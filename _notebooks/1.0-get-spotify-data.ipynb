# %%
import pandas as pd
import time
import configparser
from spotipy import Spotify
from spotipy.oauth2 import SpotifyClientCredentials
from tqdm import tqdm

# %% [markdown]
# [Documentation](https://spotipy.readthedocs.io/en/2.21.0/#examples)

# %%
# Get Spotify API tokens
parser = configparser.ConfigParser()
parser.read("../config.ini")
parser.sections()
client_id = parser.get("spotify_api", "client_id")
client_secret = parser.get("spotify_api", "client_secret")

# %%
# Authenticate credentials on API
client_credentials_manager = SpotifyClientCredentials(
    client_id=client_id, client_secret=client_secret
)
sp = Spotify(client_credentials_manager=client_credentials_manager)

# %%
# Playlist ID from the URL
playlist_id = "6HH8b0QuWuan4VM8nAD9RV"

# Get playlist tracks
results = sp.playlist_items(playlist_id)
tracks = results["items"]

# Get all tracks if there are more than 100 (pagination)
while results["next"]:
    results = sp.next(results)
    tracks.extend(results["items"])

# Extract URIs
track_uris = []
for item in tracks:
    track = item["track"]
    track_uris.append(track["uri"])
    print(f"Track: {track['name']}, URI: {track['uri']}")

print(f"Total tracks: {len(track_uris)}")
# Out:
# Track: La Balsa, URI: spotify:track:4J2xMy0kakU9sAin1uppxb
# Track: Muchacha (Ojos de Papel), URI: spotify:track:1SXzI5Rnid2ApgNQPmROLm
# Track: Rasguña las Piedras, URI: spotify:track:3lvAzKmRH8vzXQ4xm19v78
# Track: De Música Ligera - Remasterizado 2007, URI: spotify:track:2lpIh6Gr6HYjg1CFBaucS5
# Track: Ji Ji Ji, URI: spotify:track:1tW6LiJGXGlReuNP38wrKb
# Track: Sólo Le Pido A Dios, URI: spotify:track:5XxFB1oX6QvX5hrWESHIa5
# Track: Presente (El Momento en Que Estás), URI: spotify:track:4bFUkfOd1ZGrCaszcsBP2L
# Track: Seminare, URI: spotify:track:5bXhx2vO2N4ZwUi0QFn4HU
# Track: Y dale alegría a mi corazón, URI: spotify:track:48YvbZN5ndSIQuVorf48fM
# Track: Matador - Remasterizado 2008, URI: spotify:track:7d4pdMym8ZBOgf1oVPTiPb
# Track: Canción para Mi Muerte, URI: spotify:track:0t0Kl5jxxV3s8bdpILkgmd
# Track: La Rubia Tarada, URI: spotify:track:0fl226orGuKX2sjg7y7dyU
# Track: El Oso, URI: spotify:track:42WA51ZqDPtp4ZhJj2ngAB
# Track: Mil Horas, URI: spotify:track:6sBgH04G1edCBg7eC8rIdl
# Track: Tengo, URI: spotify:track:21VWhRhjxCvtXUFcUeqnBL
# Track: Demoliendo Hoteles, URI: spotify:track:29iIRrSuANyjnwag69PHOJ
# Track: Yo Vengo A Ofrecer Mi Corazon, URI: spotify:track:2PhrL2xyZCqr5OPQJirv0i
# Track: Nada que perder, URI: spotify:track:6UlD0JgjMvVXGB4J61w6hW
# Track: ¿Qué Ves?, URI: spotify:track:0aad6vDkOmu9d1aFNvOwYC
# Track: Jugo de Tomate, URI: spotify:track:0agzpJR3jRbfLKhG5nWxx3
# Track: Imágenes Paganas, URI: spotify:track:6hiXQhwO98tEbNNbWtNS1Y
# Track: Los Viejos Vinagres, URI: spotify:track:1im6qBIKkKI74toy5Htaur
# Track: Flaca, URI: spotify:track:1p7m9H4H8s0Y7SgRm7j3ED
# Track: Los Dinosaurios, URI: spotify:track:3VCKdfJAL8DTDlwZw5O6Ik
# Track: El Revelde, URI: spotify:track:24o76WATbnSIhV26hHgUHn
# Track: Verano del 92, URI: spotify:track:1NXvuBAq48QrxRFQZVmORQ
# Track: Se Viene, URI: spotify:track:3sDmwlRdEdsb1BLDChJSJV
# Track: Tirá para Arriba, URI: spotify:track:67wEz8F9d1SBBeX4IOWfck
# Track: 11 Y 6, URI: spotify:track:2PkTjm1QAJCZbJ9MqC4RqA
# Track: Los Piratas, URI: spotify:track:4vtaM6xsM7V8R1sJseCWHu
# Track: Persiana Americana - Remasterizado 2007, URI: spotify:track:71awpJoi5bqGMBrTkHDDoL
# Track: La Bestia Pop, URI: spotify:track:5WeBnrDPyLhxruxVryHCkn
# Track: Seguir Viviendo Sin Tu Amor, URI: spotify:track:2qBirMakpTdz9ymxrZEyzg
# Track: Para siempre, URI: spotify:track:12L4EdgpIWpza2vI0atLEA
# Track: Abarajame, URI: spotify:track:3uLlpzZGQCMfhM0kmuI4qn
# Track: Mi enfermedad, URI: spotify:track:46bGEqzd7anKKovVOZ9bTF
# Track: Y Lo Que Quiero Es Que Pises Sin El Suelo, URI: spotify:track:3z5F0EaY9VCq9GiQPzrbDX
# Track: Solo Se Trata de Vivir, URI: spotify:track:4vKvCed2EoxBl4DFSqSUH8
# Track: Spaghetti del Rock, URI: spotify:track:6rg1MBZqggsQ5olFGTw0rr
# Track: Mirta, De Regreso, URI: spotify:track:13OPtX7qzpaE638ytwR9zj
# Track: 1-2 Ultraviolento, URI: spotify:track:3ZFfwUQxXspg5hhJXyFR8J
# Track: Sin documentos - Edición Aniversario, URI: spotify:track:186afFfe9E4NSyFSvroz1j
# Track: Yo No Quiero Volverme Tan Loco, URI: spotify:track:68LeIVjVDRMXPlfdFHhID6
# Track: La Música, URI: spotify:track:1zigJ88daU6fdoyxjsDAeS
# Track: Hacelo por Mí, URI: spotify:track:6qoHBab3uXaz0qCXm04iTQ
# Track: El amor después del amor, URI: spotify:track:1PQzZbitOJ6XPFg7FFzsKQ
# Track: El Extraño del Pelo Largo, URI: spotify:track:684mSIt8bHBYGgIQjFsERt
# Track: En La Ciudad De La Furia - Remasterizado 2007, URI: spotify:track:7J2885UBOaG6x3LLkp2YGf
# Track: El Tren de las 16, URI: spotify:track:1YlNjGY0PzPvwOy3ALRGCx
# Track: Himno De Mi Corazón, URI: spotify:track:2kIhana7Cw57qXztsUb7NN
# Track: Vasos Vacíos - Remasterizado 2008, URI: spotify:track:3HdwGa8sGREZHJ00rhrakx
# Track: El Anillo del Capitán Beto, URI: spotify:track:23jMDvKil4frbTA35BVzBY
# Track: No Llores Por Mí, Argentina (En Vivo), URI: spotify:track:7nYOhcrbQmeetR6f4hMoVM
# Track: Un Poco de Amor Francés, URI: spotify:track:1MRhIdcloOD0uiiG3ybXGX
# Track: Loco, URI: spotify:track:0jePqZlutXGa8xz6NNyKAy
# Track: Ya No Sos Igual, URI: spotify:track:1gom5NgPAZQOjpVLyh4HML
# Track: Todo Cambia, URI: spotify:track:6UGGqx1eC9EGodHhQxxv8A
# Track: Playas Oscuras, URI: spotify:track:5N7oqsGGw7zQ8PVfAKS4XY
# Track: Susy Cadillac, URI: spotify:track:5GdNoFDCP47GFRqBjhyPkB
# Track: Ella Vendrá - Remastered, URI: spotify:track:7Gl2RyA6Vn4KdgpacprbUg
# Track: Amanece En La Ruta, URI: spotify:track:29UOHJBpXY1L1QiWaZLY8o
# Track: Gente Que No, URI: spotify:track:6z9exPeXCP5ArkqgHIsWaF
# Track: Lollipop, URI: spotify:track:6sCc07DOnWLnivJXaYvt6A
# Track: Me Gustas Mucho, URI: spotify:track:2kB1rqoTaZ3j6ChtIWGurm
# Track: Morrissey, URI: spotify:track:3jGGwpCN8mgdyqCm28VGMN
# Track: Nunca quise, URI: spotify:track:0ZAJ660VP57lLK4U7NlGOy
# Track: Sucio y Desprolijo, URI: spotify:track:3dHo3940xcnvQaci88jAgg
# Total tracks: 100

# %%
tracks = results["items"]
# Get all tracks if there are more than 100 (pagination)
while results["next"]:
    results = sp.next(results)
    tracks.extend(results["items"])

# Create empty lists to store track information
artists = []
titles = []
track_ids = []
album_names = []
release_dates = []
durations = []
popularities = []

# Extract track and album information
for item in tracks:
    track = item["track"]

    # Get all artists joined by comma
    artist_names = ", ".join([artist["name"] for artist in track["artists"]])

    title = track["name"]
    track_uri = track["uri"]
    album_name = track["album"]["name"]
    release_date = track["album"]["release_date"]

    # Duration is typically in milliseconds, convert to seconds
    duration_ms = track["duration_ms"]
    duration_sec = duration_ms / 1000  # Convert to seconds

    popularity = track["popularity"]

    # Append to lists
    artists.append(artist_names)
    titles.append(title)
    track_ids.append(track_uri)
    album_names.append(album_name)
    release_dates.append(release_date)
    durations.append(duration_sec)
    popularities.append(popularity)

# Create a DataFrame
track_df = pd.DataFrame(
    {
        "Artist": artists,
        "Title": titles,
        "Track ID": track_ids,
        "Album": album_names,
        "Release Date": release_dates,
        "Duration (sec)": durations,
        "Popularity": popularities,
    }
)

track_df.to_csv("../data/processed/100canciones_rock_argentino.csv", index=False)

track_df
# Out:
#                                      Artist  \
# 0                                 Los Gatos
# 1                                  Almendra
# 2                               Sui Generis
# 3                               Soda Stereo
# 4   Patricio Rey y sus Redonditos de Ricota
# ..                                      ...
# 95            Viuda e Hijas de Roque Enroll
# 96                             Viejas Locas
# 97                               Leo García
# 98                              Intoxicados
# 99                            Pappo's Blues
#
#                                     Title  \
# 0                                La Balsa
# 1                Muchacha (Ojos de Papel)
# 2                     Rasguña las Piedras
# 3   De Música Ligera - Remasterizado 2007
# 4                                Ji Ji Ji
# ..                                    ...
# 95                               Lollipop
# 96                        Me Gustas Mucho
# 97                              Morrissey
# 98                            Nunca quise
# 99                     Sucio y Desprolijo
#
#                                 Track ID                          Album  \
# 0   spotify:track:4J2xMy0kakU9sAin1uppxb                      Los Gatos
# 1   spotify:track:1SXzI5Rnid2ApgNQPmROLm   El 1er Álbum Más los Singles
# 2   spotify:track:3lvAzKmRH8vzXQ4xm19v78        Confesiones De Invierno
# 3   spotify:track:2lpIh6Gr6HYjg1CFBaucS5    Canción Animal (Remastered)
# 4   spotify:track:1tW6LiJGXGlReuNP38wrKb                        Oktubre
# ..                                   ...                            ...
# 95  spotify:track:6sCc07DOnWLnivJXaYvt6A             Perlas y Diamantes
# 96  spotify:track:2kB1rqoTaZ3j6ChtIWGurm                       Especial
# 97  spotify:track:3jGGwpCN8mgdyqCm28VGMN                            Mar
# 98  spotify:track:0ZAJ660VP57lLK4U7NlGOy  Otro Día en el Planeta Tierra
# 99  spotify:track:3dHo3940xcnvQaci88jAgg          Pappo's Blues, Vol. 3
#
#    Release Date  Duration (sec)  Popularity
# 0    1967-02-13         176.000          46
# 1    1992-04-01         187.786          48
# 2    1973-06-22         191.226          53
# 3    1990-10-09         212.746          76
# 4    1986-01-10         334.600           1
# ..          ...             ...         ...
# 95   2014-09-23         151.493          36
# 96   1999-01-01         199.933          66
# 97   2001-01-01         161.320          39
# 98         2005         260.371          69
# 99   1972-11-25         273.260           0
#
# [100 rows x 7 columns]

# %%
# Function to add audio features to the dataframe
def add_audio_features(df):
    # Create a list to store all audio features
    all_features = []

    # Process in batches of 100 (Spotify API limit)
    for i in range(0, len(df), 100):
        # Get track IDs for this batch
        batch_ids = df["Track ID"].iloc[i : i + 100].tolist()

        try:
            # Get audio features for batch
            features_batch = sp.audio_features(batch_ids)
            all_features.extend(features_batch)

            # Add a small delay to avoid hitting rate limits
            time.sleep(0.2)

        except Exception as e:
            print(f"Error fetching audio features for batch {i}-{i+99}: {e}")
            # Add None values for failed batch
            all_features.extend([None] * len(batch_ids))

    # Convert list of features to dataframe
    features_df = pd.DataFrame(all_features)

    # Drop redundant columns
    redundant_cols = ["id", "uri", "track_href", "analysis_url"]
    features_df = features_df.drop(
        [col for col in redundant_cols if col in features_df.columns], axis=1
    )

    # Ensure dataframes have same index for concatenation
    features_df.reset_index(drop=True, inplace=True)
    df_copy = df.copy().reset_index(drop=True)

    # Concatenate the dataframes
    result_df = pd.concat([df_copy, features_df], axis=1)

    return result_df


# Example usage
enriched_df = add_audio_features(track_df)
enriched_df
# Out:
# HTTP Error for GET to https://api.spotify.com/v1/audio-features/?ids=4J2xMy0kakU9sAin1uppxb,1SXzI5Rnid2ApgNQPmROLm,3lvAzKmRH8vzXQ4xm19v78,2lpIh6Gr6HYjg1CFBaucS5,1tW6LiJGXGlReuNP38wrKb,5XxFB1oX6QvX5hrWESHIa5,4bFUkfOd1ZGrCaszcsBP2L,5bXhx2vO2N4ZwUi0QFn4HU,48YvbZN5ndSIQuVorf48fM,7d4pdMym8ZBOgf1oVPTiPb,0t0Kl5jxxV3s8bdpILkgmd,0fl226orGuKX2sjg7y7dyU,42WA51ZqDPtp4ZhJj2ngAB,6sBgH04G1edCBg7eC8rIdl,21VWhRhjxCvtXUFcUeqnBL,29iIRrSuANyjnwag69PHOJ,2PhrL2xyZC
8xz6NNyKAy,4vTjD2aIaRySj7tVo70w4D,5eK0UAeymUyyXILUAefcj5,7fb6cCaSVGF9lGfAg4cxFi,6gwaa6ElIixNTvu6RwkMyo,1CC6c97bwIpA9G9RCuwEY2,3QyB8F5ZhYoai6qjC3evt4,1g02x46MYE1gclJfGQiQbA,4k3K6Ke6KfAWb7zyQWrTEA,6kanjFMTQN6Gm31SVvr5Ac,4c4WEv5vCGNvmQW7Gj1xzJ,411J3pP54W1K9PMo72Fg2w,2JmfB9i73m8daDafBp3sed,3uMYq07Kj5m564OQwdSCrD,1qvY1z3Wm3sAYeHfPTnrbI,4UTx1bBplNSU7dBbVNA77Y,2sTdHOegsYoU6H2w6CdCKo,0gaGh9zDdtHDlTXiMzJXjv,4MFFkZDFrKA9rW5JJUCyCh,5O5PY5HJNPxD7KyqU0SEhH,1BrVYx1UI7dsh4VFGYWpLL,3ydweVPwq9PCEVJ8WwqT6u,7uZcZ7lXte8e8rNCIRH38y,1MHNs42ZBA91ONnGjwmjyG,5BaqCOW8FaahrXIRIvU6Ad,7qx8iUyfejy6CFhSUKKZWD,6pCZYiB2ZoLfDuapZbpKl8,45VLmRZf4WmTSmTKt4bp53,5BaoWORszQDCU5ee4frtoP,7CzIIZDrVCgxwXYzhzt58d,4T2x7TnGZTjJhkQNJ4KMN5,54hZ4XVJ0xdp6teJVyHgn8,6vNaGz1KH44XJ9zRyCE81I,09XkPoMOoWRiwMkwMMcCN1,1gom5NgPAZQOjpVLyh4HML,6UGGqx1eC9EGodHhQxxv8A,5N7oqsGGw7zQ8PVfAKS4XY,5GdNoFDCP47GFRqBjhyPkB,7Gl2RyA6Vn4KdgpacprbUg,29UOHJBpXY1L1QiWaZLY8o,6z9exPeXCP5ArkqgHIsWaF,6sCc07DOnWLnivJXaYvt6A,2kB1rqoTaZ3j6ChtIWGurm,3jGGwpCN8mgdyqCm28VGMN,0ZAJ660VP57lLK4U7NlGOy,3dHo3940xcnvQaci88jAgg:
#  None, reason: None
#                                      Artist  \
# 0                                 Los Gatos
# 1                                  Almendra
# 2                               Sui Generis
# 3                               Soda Stereo
# 4   Patricio Rey y sus Redonditos de Ricota
# ..                                      ...
# 95            Viuda e Hijas de Roque Enroll
# 96                             Viejas Locas
# 97                               Leo García
# 98                              Intoxicados
# 99                            Pappo's Blues
#
#                                     Title  \
# 0                                La Balsa
# 1                Muchacha (Ojos de Papel)
# 2                     Rasguña las Piedras
# 3   De Música Ligera - Remasterizado 2007
# 4                                Ji Ji Ji
# ..                                    ...
# 95                               Lollipop
# 96                        Me Gustas Mucho
# 97                              Morrissey
# 98                            Nunca quise
# 99                     Sucio y Desprolijo
#
#                                 Track ID                          Album  \
# 0   spotify:track:4J2xMy0kakU9sAin1uppxb                      Los Gatos
# 1   spotify:track:1SXzI5Rnid2ApgNQPmROLm   El 1er Álbum Más los Singles
# 2   spotify:track:3lvAzKmRH8vzXQ4xm19v78        Confesiones De Invierno
# 3   spotify:track:2lpIh6Gr6HYjg1CFBaucS5    Canción Animal (Remastered)
# 4   spotify:track:1tW6LiJGXGlReuNP38wrKb                        Oktubre
# ..                                   ...                            ...
# 95  spotify:track:6sCc07DOnWLnivJXaYvt6A             Perlas y Diamantes
# 96  spotify:track:2kB1rqoTaZ3j6ChtIWGurm                       Especial
# 97  spotify:track:3jGGwpCN8mgdyqCm28VGMN                            Mar
# 98  spotify:track:0ZAJ660VP57lLK4U7NlGOy  Otro Día en el Planeta Tierra
# 99  spotify:track:3dHo3940xcnvQaci88jAgg          Pappo's Blues, Vol. 3
#
#    Release Date  Duration (sec)  Popularity     0
# 0    1967-02-13         176.000          46  None
# 1    1992-04-01         187.786          48  None
# 2    1973-06-22         191.226          53  None
# 3    1990-10-09         212.746          76  None
# 4    1986-01-10         334.600           1  None
# ..          ...             ...         ...   ...
# 95   2014-09-23         151.493          36  None
# 96   1999-01-01         199.933          66  None
# 97   2001-01-01         161.320          39  None
# 98         2005         260.371          69  None
# 99   1972-11-25         273.260           0  None
#
# [100 rows x 8 columns]

# %%
result = sp.audio_analysis("spotify:track:6sCc07DOnWLnivJXaYvt6A")
result
# Out:
# HTTP Error for GET to https://api.spotify.com/v1/audio-analysis/6sCc07DOnWLnivJXaYvt6A with Params: {} returned 403 due to None
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/Documents/personal/musica_arg_nlp/.venv/lib/python3.11/site-packages/spotipy/client.py:274, in Spotify._internal_call(self, method, url, payload, params)
#     269 response = self._session.request(
#     270     method, url, headers=headers, proxies=self.proxies,
#     271     timeout=self.requests_timeout, **args
#     272 )
# --> 274 response.raise_for_status()
#     275 results = response.json()
#
# File ~/Documents/personal/musica_arg_nlp/.venv/lib/python3.11/site-packages/requests/models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 403 Client Error: Forbidden for url: https://api.spotify.com/v1/audio-analysis/6sCc07DOnWLnivJXaYvt6A
#
# During handling of the above exception, another exception occurred:
#
# SpotifyException                          Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 result = sp.audio_analysis("spotify:track:6sCc07DOnWLnivJXaYvt6A")
#       2 result
#
# File ~/Documents/personal/musica_arg_nlp/.venv/lib/python3.11/site-packages/spotipy/client.py:1784, in Spotify.audio_analysis(self, track_id)
#    1778 warnings.warn(
#    1779     "You're using `audio_analysis(...)`, "
#    1780     "which is marked as deprecated by Spotify.",
#    1781     DeprecationWarning,
#    1782 )
#    1783 trid = self._get_id("track", track_id)
# -> 1784 return self._get("audio-analysis/" + trid)
#
# File ~/Documents/personal/musica_arg_nlp/.venv/lib/python3.11/site-packages/spotipy/client.py:324, in Spotify._get(self, url, args, payload, **kwargs)
#     321 if args:
#     322     kwargs.update(args)
# --> 324 return self._internal_call("GET", url, payload, kwargs)
#
# File ~/Documents/personal/musica_arg_nlp/.venv/lib/python3.11/site-packages/spotipy/client.py:294, in Spotify._internal_call(self, method, url, payload, params)
#     289         reason = None
#     291     logger.error(f"HTTP Error for {method} to {url} with Params: "
#     292                  f"{args.get('params')} returned {response.status_code} due to {msg}")
# --> 294     raise SpotifyException(
#     295         response.status_code,
#     296         -1,
#     297         f"{response.url}:\n {msg}",
#     298         reason=reason,
#     299         headers=response.headers,
#     300     )
#     301 except requests.exceptions.RetryError as retry_error:
#     302     request = retry_error.request
#
# SpotifyException: http status: 403, code: -1 - https://api.spotify.com/v1/audio-analysis/6sCc07DOnWLnivJXaYvt6A:
#  None, reason: None
